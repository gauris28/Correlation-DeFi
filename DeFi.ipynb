# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel (r'Correlation.xlsx')

# %%
print(df)
# Out:
#           Date      BTC      ETH      UNI   LINK     LUNA    AAVE    CAKE  \
# 0   2020-04-01   6638.5   135.66      NaN   2.28      NaN    0.02     NaN
# 1   2020-04-02   6800.5   141.30      NaN   2.29      NaN    0.02     NaN
# 2   2020-04-03   6735.9   141.14      NaN   2.30      NaN    0.02     NaN
# 3   2020-04-04   6857.4   144.01      NaN   2.30      NaN    0.02     NaN
# 4   2020-04-05   6772.7   142.58      NaN   2.27      NaN    0.02     NaN
# ..         ...      ...      ...      ...    ...      ...     ...     ...
# 383 2021-04-19  55646.1  2160.63  31.4223  35.74  13.8871  344.06  22.849
# 384 2021-04-20  56483.2  2332.14  31.9898  39.01  13.4417  360.49  27.502
# 385 2021-04-21  53820.2  2360.81  33.4146  36.28  13.2607  351.11  26.118
# 386 2021-04-22  51729.5  2401.10  33.9543  35.20  13.6291  360.05  25.129
# 387 2021-04-23  49662.7  2304.70  31.6782  33.44  13.4369  334.00  25.103
#
#          MKR     DAI    COMP   SUSHI
# 0        NaN     NaN     NaN     NaN
# 1        NaN  1.0109     NaN     NaN
# 2        NaN  1.0228     NaN     NaN
# 3        NaN  1.0100     NaN     NaN
# 4     297.83  1.0156     NaN     NaN
# ..       ...     ...     ...     ...
# 383  3519.59  0.9926  477.65  12.155
# 384  3454.27  0.9950  485.59  12.737
# 385  4025.79  0.9962  492.83  12.471
# 386  4017.96  0.9952  529.98  12.316
# 387  4019.98  0.9926  615.37  11.325
#
# [388 rows x 12 columns]

# %%
corrMatrix =df.corr()

# %%
corrMatrix =df.corr()

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), annot = True, fmt='.1g')
# Out:
# <AxesSubplot:>

# %%
matrix = np.triu(df.corr())

# %%
sns.heatmap(df.corr(), annot=True, cbar_kws= {'orientation': 'horizontal'}, mask=matrix)
# Out:
# <AxesSubplot:>
